# %% [markdown]
# positional argument =

# %%
def num(num1,num2,num3):
    print(num1 ,num2 ,num3)
    return num1 + num2 + num3

# %%
num(2, 3 ,5)
# Out:
# 2 3 5
# 10

# %% [markdown]
# keyword argument

# %%
def add(num1 =3 ,num2 =4 ,num3=6):
    print(num1, num2,num3)
    return num1 + num2 + num3

# %%
add()
# Out:
# 3 4 6
# 13

# %% [markdown]
# default pearameter

# %% [markdown]
# default peremiter means the value is store is defaiult

# %%
def add(num1=1, num2=2, num3=3):
    print(f'num1: {num1}, num2: {num2}, num3: {num3}')
    return num1 + num2 + num3

# %%
add()
# Out:
# num1: 1, num2: 2, num3: 3
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def display_massage():
    print('hello today is my best and worst day of my life')

# %%
display_massage()
# Out:
# hello today is my best and worst day of my life

# %%
def favourite_books(title):
    print(f'my favourite book is {title}')
    return title

# %%
favourite_books('alice in borderland')
# Out:
# my favourite book is alice in borderland
# 'alice in borderland'

# %% [markdown]
# ![alt text](image.png)

# %%
def make_shirts(size , text):
    print(f'size : {size}\ntext : {text}')

# %%
make_shirts(89,'afridi')
# Out:
# size : 89
# text : afridi

# %%
def modify_make_shirts(size = 'large', text = 'i love python'):
    print(f'size : {size}\ntext : {text}')

# %%
modify_make_shirts('medium')
# Out:
# size : medium
# text : i love python

# %%
def describe_cities(city,country ='pakistan'):
    print(f'{city} is in {country}')

# %%
describe_cities('karachi')
# Out:
# karachi is in pakistan

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def album(singer,song):
    result = [singer , song]
    return result

# %%
album('atif aslam', "aadat")
# Out:
# ['atif aslam', 'aadat']

# %%
def make_album(artist, album):
    result = {artist: album}
    return result

# %%
make_album('atif aslam', 'anyalbum')
# Out:
# {'atif aslam': 'anyalbum'}

# %%
def make_album(artist, album, song=None):
    if song:
        result = {artist: album, 'song':song}
    else:
        result = {artist: album}
    return result

# %%
make_album('atif aslam', 'jaal','')
# Out:
# {'atif aslam': 'jaal', 'song': 'song'}

# %%
songs = None
bool(songs)
# Out:
# False

# %%
def make_album():
    flag = True
    result = {}
    while flag:
        artist = input('Enter artist name: ')
        album = input('Enter album name: ')
        result.update({artist: album})
        if artist.lower:
            break
      
    return result

# %%
make_album()
# Out:
# {'atif aslam': 'kuch bhi'}

# %%
def city_country(city , country):
    print(f'({city} , {country}) ')

# %%
city_country('karachi','lahore')
# Out:
# (karachi , lahore)
