# %% [markdown]
# LOOPS

# %%
print('HELLO')
print('HELLO')
print('HELLO')
print('HELLO')
print('HELLO')
print('HELLO')
print('HELLO')
# Out:
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO
# HELLO

# %% [markdown]
# -for
#                   -while

# %%
range(10)

# %%
#for variable in iterable:
    # do something with variable

# %%
# Iterable = Anything which can be looped over
# for i in iterable:
for i in range(1,11):
    print(f'{i}- hello')

# 1- hello
# 2- hello
# Out:
# 1- hello
# 2- hello
# 3- hello
# 4- hello
# 5- hello
# 6- hello
# 7- hello
# 8- hello
# 9- hello
# 10- hello

# %%
for aman in range(1,11):
    print(f'{aman} -hello')
# Out:
# 1 -hello
# 2 -hello
# 3 -hello
# 4 -hello
# 5 -hello
# 6 -hello
# 7 -hello
# 8 -hello
# 9 -hello
# 10 -hello

# %%
hello = 'aman'
for a in range(10):
    print(f' {a} -{hello} siddiqui') #the loop
# Out:
#  0 -aman siddiqui
#  1 -aman siddiqui
#  2 -aman siddiqui
#  3 -aman siddiqui
#  4 -aman siddiqui
#  5 -aman siddiqui
#  6 -aman siddiqui
#  7 -aman siddiqui
#  8 -aman siddiqui
#  9 -aman siddiqui

# %%
# 1 to 20 
for num in range(2, 10, 2):      # range(start:stop:step)
    print(num)
# Out:
# 2
# 4
# 6
# 8

# %%
for a in range(1,10,2):
     print(f' {a} - odd')
# Out:
#  1 - odd
#  3 - odd
#  5 - odd
#  7 - odd
#  9 - odd

# %%
hello = 'aman'
for a in hello:
    print(f'-{hello} siddiqui')
# Out:
# -aman siddiqui
# -aman siddiqui
# -aman siddiqui
# -aman siddiqui

# %%
cities = ['karachi','muree','lahore','multan']
for city in cities:
    if len (city) % 2 == 0 :          # % is used to check reminder means if we devide city to 2 so how much reminder it gives.
        print(city)
# Out:
# lahore
# multan

# %%
print(city)
# Out:
# multan

# %%
cities = ['karachi','muree','lahore','multan']
for city in cities:
    if city.count('a') == 2:
        print("okay")
# Out:
# okay

# %%
for sufiyan in cities:
    if len(sufiyan) <=6:
        print(sufiyan)
# Out:
# muree
# lahore
# multan

# %%
# [ 6, 2, 1, 8, 10 ] => 16
nums = [ 6, 2, 1, 8, 10 ]
nums.remove(max(nums))
nums.remove(min(nums))
print(sum(nums))
# Out:
# 16

# %%
nums = [1, 1, 11, 2, 3]
nums.remove(max(nums))
nums.remove(min(nums))
print(sum(nums))
# Out:
# 6

# %%
nums = []
nums.remove(max(nums))
nums.remove(min(nums))
print(sum(nums))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 nums = []
# ----> 2 nums.remove(max(nums))
#       3 nums.remove(min(nums))
#       4 print(sum(nums))
#
# ValueError: max() iterable argument is empty

# %%
nums.sort()
nums[1:-1]
# Out:
# [1, 2, 3]

# %%
nums = [1,3,12]
if nums:
    nums.sort()
    result = sum(nums[1:-1])
    print(result)
else:
    print(0)
# Out:
# 3
