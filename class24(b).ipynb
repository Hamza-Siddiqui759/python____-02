# %%
with open('testing1.txt') as f :
    f.seek(0)
    a= f.readlines()

# %%
a
# Out:
# ['pakistan phir se wahi naya content']

# %%
dummy = 'kuch bhi\nkuch nai'

# %%
print(dummy)
dummy.split('\n')
# Out:
# kuch bhi
# kuch nai
# ['kuch bhi', 'kuch nai']

# %%
a
# Out:
# ['pakistan phir se wahi naya content']

# %%
with open('testing1.txt','a+') as e:
    e.write('pakistan is my favoirite country\n')
    e.seek(0)
    a = e.readline()
print(a)
# Out:
# pakistan is my favoirite country

# %%
a
# Out:
# 'pakistan is my favoirite country\n'

# %%
n = a.split('\n')

''.join(n).split(',')
# Out:
# ['pakistan is my favoirite country']

# %%
with open('testing1.txt','a+') as h:
    k =h.writelines(['pakistan is my\n','favoirite country\n'])
print(k)
# Out:
# None

# %%
with open('testing1.txt','+w') as s:
    s.write('i love python\n')
    s.write('i love to study python\n')
    s.write('i love to read python')
    s.seek(0)
    a = s.read()
    f =a.replace('python','java')
    print(f)
# Out:
# i love java
# i love to study java
# i love to read java

# %%
text =""" i love to learn python
i like to read ptyhon 
 i like to fuc k python"""

# %%
text
new = text.replace('python','java')
a =new.split('\n')
f = (tuple(a))
''.join(f)
# Out:
# ' i love to learn javai like to read ptyhon  i like to fuc k java'

# %%
with open('testing1.txt' , 'w+') as p:
    p.write('i love python\n')
    p.write('i love to read python\n')
    p.write('i love to fuck python\n')
    p.seek(0)
    lineone = p.readline()    
    linetwo = p.readline()    
    linethree = p.readline()

    update_one = 'i love to fuck python\n'
    update_two = 'i love to fuck laravel\n'
    update_three = 'i love to fuck java\n'
    p.seek(0)
    p.write(update_one)
    p.write(update_two)
    p.write(update_three)
    p.seek(0)
    a = p.read()
    print(a)
    # The .seek(0) takes keyboard cursor to 0 index and read from 0 thats why the first programme dosent run because w+ remove previous progrmme
# Out:
# i love to fuck python
# i love to fuck laravel
# i love to fuck java

# %%
with open('learning_python.txt', 'w+') as f:
    f.write("i love python\n")
    f.write("i practice python\n")
    f.write("i sometime practice python\n")
    f.seek(0)
    lineone = f.readline()    
    linetwo = f.readline()    
    linethree = f.readline()

    updatedone = "i love java\n"    
    updatedtwo = "i practice java\n"    
    updatedthree = "i sometime practice java\n"   
    f.seek(0)
    f.write(updatedone)
    f.write(updatedtwo)
    f.write(updatedthree)

    f.seek(0)

    content = f.read()
    

    # print(content)
print(content)
# Out:
# i love java
# i practice java
# i sometime practice java
# thon

# %%
def fun(name , sports):
    with open('testing1.txt','w') as a :
        e = a.write(f'{name.title()} : {sports.title()}')
        print(f'{name.title()} : {sports.title()}')

# %%
fun('ali khan' ,'tennis')
# Out:
# Ali Khan : Tennis

# %%
def fin():
    
    flag = True
    while flag:
        name = input('enter your target neme')
        sports = input('enter your target sports')
        if name == 'q' or sports == 'q':
            print('fuck you')
            flag = False
        else:
            
         with open('testing.txt','a+') as g:
          g.write(f'{name.title()} : {sports.title()}\n')           
          print(f'{name.title()} : {sports.title()}\n')

# %%
fin()
# Out:
# Aman : Cricket
#
# Rahim : Foosball
#
# Talha  : Yemmis
#
# fuck you
