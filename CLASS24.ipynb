# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = open('testing1.txt', 'r+')

# %%
f.write('pakistan')
# Out:
# 8

# %%
f.read()
# Out:
# 'tent phir se wahi naya content'

# %%
f.close()

# %%
f = open('testing1.txt', 'w+')

# %%
f.write('naya content')
# Out:
# 12

# %%
f.seek(0) # it takes cursor at start index 0
# Out:
# 0

# %%
f.read()
# Out:
# 'naya content'

# %%
f.close()

# %%
f = open('testing1.txt', 'a+')

# %%
f.write(' phir se wahi naya content')
# Out:
# 26

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# 'naya content phir se wahi naya content'

# %%
f.close()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('testing1.txt') as f:
      content = f.read()

# %%
content
# Out:
# 'naya content phir se wahi naya content'

# %%
with open('new file' , 'w+') as e: # the benefit of this code that you dont have to close that 
    e.write('hi first line')
    e.seek(0)
    context = e.read()

# %%
context
# Out:
# 'hi first line'

# %%
with open('new file' , 'w') as w:
    w.write(' hi ')
    w.seek(0)
    w.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[40], line 4
#       2 w.write(' hi ')
#       3 w.seek(0)
# ----> 4 w.read()
#
# UnsupportedOperation: not readable

# %%
with open("testing1.txt" ,"a+") as o:
     o.seek(0)
     ok =o.read()

# %%
ok
# Out:
# 'naya content phir se wahi naya content'
