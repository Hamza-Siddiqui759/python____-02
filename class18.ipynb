# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def make_album(artist, album, song=None):
    if song:
        result = {artist: album, 'song':song}
    else:
        result = {artist: album}
    return result

# %%
make_album('artist', ' talha anjum' , 'haath baandh')
# Out:
# {'artist': ' talha anjum', 'song': 'haath baandh'}

# %%
def make_album():
    flag = True
    result = {}
    while flag:
        artist = input('Enter Artist name: ')
        album = input('Enter Album name: ')
        if artist == 'q' or album == 'q':
            break
        else:
            result[artist] = album
    return result

# %%
make_album()
# Out:
# {'atif': 'aslam'}

# %%
def make_album():
    result = {}
    while True:
        artist = input('Enter Artist name (or "q" to quit): ')
        if artist.lower() == 'q':
            break
        album = input('Enter Album name (or "q" to quit): ')
        if album.lower() == 'q':
            break
        result[artist] = album
    return result

print(make_album())
# Out:
# {'aman': 'aman'}

# %% [markdown]
# Arbitrary Number of Arguments

# %%
def any_function(param1):
    
    return param1

# %%
any_function( 'ali khan')
# Out:
# 'ali khan'

# %%
def make_pizza(*toppings): # * this star means that steering that wuth the help of this yiou can write as many un this parameter
    print(toppings)

# %%
make_pizza('pepproni', 'onion')
make_pizza('pepproni', 'onion', 'Bacon')
make_pizza('pepproni', 'onion', 'Bacon', 'Prosciutto')
# Out:
# ('pepproni', 'onion')
# ('pepproni', 'onion', 'Bacon')
# ('pepproni', 'onion', 'Bacon', 'Prosciutto')

# %%
def make_tyre(tyres ,*tyres_type):
    print(f'this {tyres} tyre is way more beautuiful than you think and that {tyres_type} of tyres are not reliable')

# %%
make_tyre('servis','panther' , 'service','duke')
# Out:
# this servis tyre is way more beautuiful than you think and that ('panther', 'service', 'duke') of tyres are not reliable

# %%
def make_pizza(size ,*toppings):
    print(f'Make {16} inch pizza with following toppings:')
    for topping in toppings:
        print(f' -{topping}')

# %%
make_pizza(16,'papperoni', 'onion' , 'jallapenno')
# Out:
# Make 16 inch pizza with following toppings
#  -papperoni
#  -onion
#  -jallapenno

# %%
def make_sandwichis(pieces ,*title):
    print(f'The {pieces} pieces amount in {title} sandwiches is too much. ')
    for total in title:  
        print(f'-{total}')

# %%
make_sandwichis(16 , 'jallapenno' , 'garlic', 'extra cheeze')
# Out:
# The 16 pieces amount in ('jallapenno', 'garlic', 'extra cheeze') sandwiches is too much.
# -jallapenno
# -garlic
# -extra cheeze

# %% [markdown]
# double steeric

# %%
def build_info( **info):
    return info

# %%
build_info(fname = 'ali' , lname = 'khan' )
# Out:
# {'fname': 'ali', 'lname': 'khan'}

# %%
def build_car(manf , model ,**features):
    if features:
        print(f'The {manf} company and {model} model of this car is awesome and also its features:')
        for key , value in features.items():
            print(f'- {key} : {value}')
    else:
       print(f'The {manf} company and {model} model of this car is awesome:')

# %%
build_car('toyota' , '2019' , colours = 'black')
# Out:
# The toyota company and 2019 model of this car is awesome and also its features:
# - colours : black

# %%
build_car('Toyota', 'Gli')
# Out:
# The Toyota company and Gli model of this car is awesome:

# %%
def longest_word(s):
    words = s.split()
    longest = ""
    
    for word in words:
        if len(word) > len(longest):
            longest = word
    
    return longest

print(longest_word("I love programming in Python"))
# Out:
# programming

# %%
def longest_word(s):

    words = s.split()
    longest = ""

    for word in words:
        if len(word) > len(longest):
            longest = word

    return longest

# %%
longest_word('love python bavbbbb')
# Out:
# 'bavbbbb'

# %%
def words(s):
    wording = s.split()
    longest = ""
    
    for words in wording:
        if len(words) > len(longest):
            longest = words
    return longest

# %%
words('i hate python babe')
# Out:
# 'python'
