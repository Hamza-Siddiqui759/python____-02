# %%
flag = True
data = {}
while flag:
     name = input('Enter your name')
     sports =  input('Enter youe sports name')
     if name == 'q' or sports == 'q':
            flag = False
            print('fuck you')
     else:
        if name not in data:
         data [name] = [sports]
        else:
             data[name].append(sports)
with open('testing.txt','a') as g:
        for name, sport in data.items():
             g.write(f"{name}: {', '.join(sport)}\n")
# Out:
# fuck you

# %%
def dun():
    flag = True
    data = {}
    while flag:
        name = input('name')
        sports = input('sports')
        if name == 'q' and sports == 'q':
            flag  =False
            print('fuck you')
        else:
            if name not in data:
                data [name] = [sports]
            else:
                data[name].append(sports)
    with open('testing.txt','a+') as f:
        for name,sports in data.items():
            f.write(f'{name}:{', '.join(sports)}\n')

# %%
dun()
# Out:
# fuck you

# %%
def function():
    flag = True
    data ={}
    while flag:
        name =input('name')
        sports = input('sports')
        if name == 'q' or sports =='q' :
            flag = False
        else:
            if name not in data:
                data[name]= [sports]
            else:
                data[name].append(sports)
    with open('testing.txt','a+') as f:
        for name,sports in data.items():
            f.write(f'{name}:{', '.join(sports)}\n')

# %%
function()
