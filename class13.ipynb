# %% [markdown]
# Multiple Conditional statements

# %%
payment_method = input('enter your payment method:').title()
address = input('enter your address :')
if payment_method in ('Cash', 'bank','card') and address:
    print(f'recieve your payment: from {address}')
else:
    print(f'no you can not  access  that {payment_method}  payment')
# Out:
# recieve your payment: from paksitan

# %%
marks = float(input('enter your marks:'))
if marks < 0 or marks > 100:
    grade = (f'invalid marks {marks}')
elif 70 <= marks < 80:
    grade ='b'
elif 60 <= marks < 70:
    grade = 'c'
elif 50 <= marks < 60:
    grade = 'd'
else:
    grade = 'fail'

print(grade)
# Out:
# d

# %%
marks = float(input('Enter student marks: '))
if marks > 100 or marks < 0:
    result = f"Invalid marks i.e. {marks}"
elif 80 <= marks <= 100:
    result = 'A1'
elif 70 <= marks < 80:
    result = 'A'
elif 60 <= marks < 70:
    result = 'B'
elif 50 <= marks < 60:
    result = 'C'
elif 40 <= marks < 50:
    result = 'D'
else:
    result = 'Better Luck Next Time'


print(result)
# Out:
# D

# %% [markdown]
# Nested_Conditions

# %%
attendence =(input('enter your attendence presentor absent:'))
marks = float(input('enter your marks'))
if attendence == 'present':
    if marks <= 100:
        if marks >= 0:
            print(f'valid attendence and marks {attendence} {marks}')
        else:
            print('welldone ')
    else:
        print(f'your marks {marks} is good')
else:
    print(f' you should always be {attendence}')
# Out:
# valid attendence and marks present 80.0

# %% [markdown]
# suzuki, 150, 2025, black

# %%
company = input('enter your desire company:').title()
if company == 'Suzuki':
    model = int(input('enter your desired model'))
    if model == 150 :
        year = int(input('enter your desire year:'))
        if year in (2025 ,2026 ,2028) :
            colour = input('enter your favourite color')
            if colour == 'balck':
                print(f'yes pack kardo bhai {company}')
            else:
                print(f'its not my desire color {colour}')
        else:
            print(f'its not my desired year {year}')
    else:
        print(f'it si not my desire model {model}')
else:
    print(f'no bhai rehne do {company}')
# Out:
# yes pack kardo bhai Suzuki
